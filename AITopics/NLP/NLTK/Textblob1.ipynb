# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from textblob) (3.9.3)
# Requirement already satisfied: click in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from nltk>=3.9->textblob) (8.3.1)
# Requirement already satisfied: joblib in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from nltk>=3.9->textblob) (2026.2.28)
# Requirement already satisfied: tqdm in /Users/premkumargontrand/AITrainingMar2026/AITrainingMarch2026/lib/python3.12/site-packages (from nltk>=3.9->textblob) (4.67.3)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.0/625.0 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.0
#
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [raw]
# from textblob import TextBlob

# %%
text = "NCCL provides routines such as all-gather, all-reduce, broadcast, reduce, reduce-scatter, and point-to-point send and receive"

# %%
blob = TextBlob(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 blob = TextBlob(text)
#
# NameError: name 'TextBlob' is not defined
